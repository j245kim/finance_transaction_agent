# %% [markdown]
# # 라이브러리

# %%
# 파이썬 표준 라이브러리
from pathlib import Path

# 파이썬 서드파티 라이브러리
import pandas as pd
from bs4 import BeautifulSoup, Comment
from pymongo import MongoClient

# %% [markdown]
# # 전역 변수 및 환경 설정

# %%
# 경로
current_dir = Path().resolve().parent
hankyung_path = rf'{current_dir}\datas\news_data\hankyung_data.json'
maekyung_path = rf'{current_dir}\datas\news_data\maekyung_data.json'
yna_path = rf'{current_dir}\datas\news_data\yna_data.json'

# %% [markdown]
# # Main

# %% [markdown]
# ## hankyung

# %%
hankyung_df = pd.read_json(hankyung_path, orient='records', encoding='utf-8', dtype='string')

# %%
hankyung_df.head()
# Out:
#                             news_title news_first_upload_time  \
# 0           송재혁 삼성전자 CTO, 차기 반도체협회장 내정    2025-02-04 18:29:00
# 1              美 관세유예에 웃었지만…코스피 '살얼음판'    2025-02-04 18:02:00
# 2  딥시크에 맞서 한·미·일 뭉쳤다…AI 반도체 개발 협력 '시동'    2025-02-04 17:38:00
# 3               이재용·올트먼·손정의 'AI 3각 동맹'    2025-02-04 17:36:00
# 4           송재혁 삼성전자 CTO, 차기 반도체협회장 내정    2025-02-04 15:23:00
#
#   news_last_upload_time                             news_author  \
# 0   2025-02-04 18:29:00                                  황정수 기자
# 1   2025-02-04 18:02:00                                  이시은 기자
# 2   2025-02-04 19:36:00                          황정수 기자, 김형규 기자
# 3   2025-02-04 19:54:00  박의명 기자, 오현우 기자, 황정수 기자, 김형규 기자, 임대철 기자
# 4   2025-02-04 15:30:00                                  황정수 기자
#
#                                         news_content  \
# 0  <div class="article-body" id="articletxt" item...
# 1  <div class="article-body" id="articletxt" item...
# 2  <div class="article-body" id="articletxt" item...
# 3  <div class="article-body" id="articletxt" item...
# 4  <div class="article-body" id="articletxt" item...
#
#                                          news_url news_category news_website  \
# 0  https://www.hankyung.com/article/2025020431091        반도체·전자         한국경제
# 1  https://www.hankyung.com/article/2025020430481        반도체·전자         한국경제
# 2  https://www.hankyung.com/article/2025020431341        반도체·전자         한국경제
# 3  https://www.hankyung.com/article/2025020430551        반도체·전자         한국경제
# 4  https://www.hankyung.com/article/202502042551i        반도체·전자         한국경제
#
#   note
# 0   산업
# 1   산업
# 2   산업
# 3   산업
# 4   산업

# %%
hankyung_df.tail()
# Out:
#                                          news_title news_first_upload_time  \
# 7955                 "그야말로 불타고 있다"…30년 만에 연초부터 '불장'    2024-01-22 08:34:00
# 7956  채권 안 산다는 '채권왕'…비트코인 '4가지 시나리오' [김현석의 월스트리트나우]    2024-01-10 07:29:00
# 7957                     "금리 낮추기 전에 잡자"…美국채 매수열기 후끈    2024-01-08 18:18:00
# 7958                 "금리 고점 잡아라"…美 채권 시장서 불붙은 매수 경쟁    2024-01-08 15:08:00
# 7959           "우버, 이자비용 수천만불 아껴"…주춤했던 美 CB시장 되살아났다    2024-01-04 09:58:00
#
#      news_last_upload_time news_author  \
# 7955   2024-01-22 09:19:00      김리안 기자
# 7956   2024-01-10 08:17:00      김현석 기자
# 7957   2024-01-09 00:48:00      오현우 기자
# 7958   2024-01-08 15:13:00      오현우 기자
# 7959   2024-01-04 10:07:00      장서우 기자
#
#                                            news_content  \
# 7955  <div class="article-body" id="articletxt" item...
# 7956  <div class="article-body" id="articletxt" item...
# 7957  <div class="article-body" id="articletxt" item...
# 7958  <div class="article-body" id="articletxt" item...
# 7959  <div class="article-body" id="articletxt" item...
#
#                                             news_url news_category  \
# 7955  https://www.hankyung.com/article/202401220077i            채권
# 7956  https://www.hankyung.com/article/202401103544i            채권
# 7957  https://www.hankyung.com/article/2024010898721            채권
# 7958  https://www.hankyung.com/article/202401088873i            채권
# 7959  https://www.hankyung.com/article/202401041220i            채권
#
#      news_website    note
# 7955         한국경제  글로벌 마켓
# 7956         한국경제  글로벌 마켓
# 7957         한국경제  글로벌 마켓
# 7958         한국경제  글로벌 마켓
# 7959         한국경제  글로벌 마켓

# %%
hankyung_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7960 entries, 0 to 7959
# Data columns (total 9 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   news_title              7960 non-null   string
#  1   news_first_upload_time  7960 non-null   string
#  2   news_last_upload_time   7960 non-null   string
#  3   news_author             7809 non-null   string
#  4   news_content            7960 non-null   string
#  5   news_url                7960 non-null   string
#  6   news_category           7960 non-null   string
#  7   news_website            7960 non-null   string
#  8   note                    7960 non-null   string
# dtypes: string(9)
# memory usage: 559.8 KB

# %% [markdown]
# ## maekyung

# %%
maekyung_df = pd.read_json(maekyung_path, orient='records', encoding='utf-8', dtype='string')

# %%
maekyung_df.head()
# Out:
#                            news_title news_first_upload_time  \
# 0  무역전쟁엔 스페셜티 기업이 성공··· “2월은 저가매수 기회”    2025-02-04 18:11:00
# 1          아이에스티이·동방메디컬, 일반청약서 나란히 선방    2025-02-04 17:59:00
# 2            LG CNS 공모 흥행에 촉각 곤두세운 SK    2025-02-04 17:33:00
# 3             '한국판 ASML' HPSP 인수후보 압축    2025-02-04 17:33:00
# 4        신창재 교보생명 회장 "풋옵션 가격 산정 늦춰달라"    2025-02-04 17:32:00
#
#   news_last_upload_time     news_author  \
# 0                  <NA>          정재원 기자
# 1                  <NA>          우수민 기자
# 2   2025-02-04 19:08:00  오대석 기자, 우수민 기자
# 3   2025-02-04 19:10:00  나현준 기자, 오대석 기자
# 4   2025-02-04 20:40:00          나현준 기자
#
#                                         news_content  \
# 0  <div class="news_detail_wrap">
#  <div style="di...
# 1  <div class="news_detail_wrap">
#  <div style="di...
# 2  <div class="news_detail_wrap">
#  <span style="b...
# 3  <div class="news_detail_wrap">
#  <span style="b...
# 4  <div class="news_detail_wrap">
#  <span style="b...
#
#                                   news_url news_category news_website note
# 0  https://stock.mk.co.kr/news/view/654885     종목분석·기업정보         매일경제   마켓
# 1  https://stock.mk.co.kr/news/view/654870     종목분석·기업정보         매일경제   마켓
# 2  https://stock.mk.co.kr/news/view/654850     종목분석·기업정보         매일경제   마켓
# 3  https://stock.mk.co.kr/news/view/654849     종목분석·기업정보         매일경제   마켓
# 4  https://stock.mk.co.kr/news/view/654843     종목분석·기업정보         매일경제   마켓

# %%
maekyung_df.tail()
# Out:
#                                        news_title news_first_upload_time  \
# 3735  화장품 용기 강소기업 네스필러PKG,  세계 최대 하이브리드 패키징업체에 팔려    2024-01-02 10:25:00
# 3736          “SK하이닉스, 당장의 실적보다 더 나은 올해에 주목”…목표가↑    2024-01-02 08:13:00
# 3737         1조원 이상 M&A ‘빅딜’ 반토막…대기업조차 ‘돈줄’ 꽉 막혔다    2024-01-02 06:15:00
# 3738                                 M&A 빅딜이 실종됐다    2024-01-01 17:31:00
# 3739   [레이더M] 1조이상 대형M&A '반토막'… 삼일PwC 재무·회계자문 2관왕    2024-01-01 17:20:00
#
#      news_last_upload_time             news_author  \
# 3735   2024-01-04 08:18:00                  강두순 기자
# 3736                  <NA>             백지연 매경닷컴 기자
# 3737                  <NA>  나현준 기자, 강두순 기자, 전형민 기자
# 3738   2024-01-01 19:57:00  나현준 기자, 강두순 기자, 전형민 기자
# 3739   2024-01-01 23:11:00  나현준 기자, 강두순 기자, 전형민 기자
#
#                                            news_content  \
# 3735  <div class="news_detail_wrap">
#  국내 화장품 패키징 공급업...
# 3736  <div class="news_detail_wrap">
#  <div style="wi...
# 3737  <div class="news_detail_wrap">
#  <div style="di...
# 3738  <div class="news_detail_wrap">
#  <span style="b...
# 3739  <div class="news_detail_wrap">
#  <span style="b...
#
#                                      news_url news_category news_website note
# 3735  https://stock.mk.co.kr/news/view/326487     종목분석·기업정보         매일경제   마켓
# 3736  https://stock.mk.co.kr/news/view/326242     종목분석·기업정보         매일경제   마켓
# 3737  https://stock.mk.co.kr/news/view/326222     종목분석·기업정보         매일경제   마켓
# 3738  https://stock.mk.co.kr/news/view/326184     종목분석·기업정보         매일경제   마켓
# 3739  https://stock.mk.co.kr/news/view/326182     종목분석·기업정보         매일경제   마켓

# %%
maekyung_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3740 entries, 0 to 3739
# Data columns (total 9 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   news_title              3740 non-null   string
#  1   news_first_upload_time  3740 non-null   string
#  2   news_last_upload_time   749 non-null    string
#  3   news_author             3740 non-null   string
#  4   news_content            3740 non-null   string
#  5   news_url                3740 non-null   string
#  6   news_category           3740 non-null   string
#  7   news_website            3740 non-null   string
#  8   note                    3740 non-null   string
# dtypes: string(9)
# memory usage: 263.1 KB

# %% [markdown]
# ## yna

# %%
yna_df = pd.read_json(yna_path, orient='records', encoding='utf-8', dtype='string')

# %%
yna_df.head()
# Out:
#                                    news_title news_first_upload_time  \
# 0       모건스탠리 "무역 리스크에 亞기술주 단기적으로 20% 하락 가능성"    2025-02-04 15:05:00
# 1           딥시크 쇼크 속 'AI 방산' 美 팔란티어 주가 23% 급등    2025-02-04 10:48:00
# 2         미래에셋증권 "해외주식 증여 고객, 1년새 5배 이상으로 증가"    2025-02-04 10:48:00
# 3         급락했던 美GM·포드 주가, 멕시코·加 관세유예에 '완전 만회'    2025-02-04 08:20:00
# 4  애플, '中 관세' 예고에 주가 3.4%↓…"수입 비용 취약 보여줘"(종합)    2025-02-04 07:00:00
#
#   news_last_upload_time news_author  \
# 0                  <NA>      주종국 기자
# 1                  <NA>      주종국 기자
# 2                  <NA>      조성흠 기자
# 3                  <NA>      이지헌 기자
# 4                  <NA>        <NA>
#
#                                         news_content  \
# 0  <article class="story-news article">
#  <div cla...
# 1  <article class="story-news article">
#  <div cla...
# 2  <article class="story-news article">
#  <div cla...
# 3  <article class="story-news article">
#  <div cla...
# 4  <article class="story-news article">
#  <div cla...
#
#                                             news_url news_category  \
# 0  https://www.yna.co.kr/view/AKR2025020411470000...          해외주식
# 1  https://www.yna.co.kr/view/AKR2025020406500000...          해외주식
# 2  https://www.yna.co.kr/view/AKR2025020406860000...          해외주식
# 3  https://www.yna.co.kr/view/AKR2025020402770007...          해외주식
# 4  https://www.yna.co.kr/view/AKR2025020400445109...          해외주식
#
#   news_website note
# 0         연합뉴스  마켓+
# 1         연합뉴스  마켓+
# 2         연합뉴스  마켓+
# 3         연합뉴스  마켓+
# 4         연합뉴스  마켓+

# %%
yna_df.tail()
# Out:
#                                news_title news_first_upload_time  \
# 995      주유소 기름값 8주 연속 상승…"환율 강세로 상승폭 확대"    2024-12-07 06:01:00
# 996  [뉴욕유가] 글로벌 수요 우려에 사흘째 하락…WTI, 1.61%↓    2024-12-07 05:46:00
# 997     "오픈AI, 범용인공지능 달성시 MS도 이용가능 방안 논의"    2024-12-07 04:50:00
# 998     비트코인 10만달러 재돌파…이더리움 9개월만에 4천달러 돌파    2024-12-07 03:43:00
# 999      [특파원 시선] 베트남마저 중국산 초저가 상품 '공습경보'    2024-12-07 00:07:00
#
#     news_last_upload_time news_author  \
# 995                  <NA>        <NA>
# 996                  <NA>      김성진 기자
# 997                  <NA>        <NA>
# 998                  <NA>        <NA>
# 999                  <NA>      박진형 기자
#
#                                           news_content  \
# 995  <article class="story-news article">
#  <div cla...
# 996  <article class="story-news article">
#  <div cla...
# 997  <article class="story-news article">
#  <div cla...
# 998  <article class="story-news article">
#  <div cla...
# 999  <article class="story-news article">
#  <div cla...
#
#                                               news_url news_category  \
# 995  https://www.yna.co.kr/view/AKR2024120613460000...         글로벌시장
# 996  https://www.yna.co.kr/view/AKR2024120700630000...         글로벌시장
# 997  https://www.yna.co.kr/view/AKR2024120700510009...         글로벌시장
# 998  https://www.yna.co.kr/view/AKR2024120700370009...         글로벌시장
# 999  https://www.yna.co.kr/view/AKR2024120615200008...         글로벌시장
#
#     news_website note
# 995         연합뉴스  마켓+
# 996         연합뉴스  마켓+
# 997         연합뉴스  마켓+
# 998         연합뉴스  마켓+
# 999         연합뉴스  마켓+

# %%
yna_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 9 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   news_title              1000 non-null   string
#  1   news_first_upload_time  1000 non-null   string
#  2   news_last_upload_time   0 non-null      string
#  3   news_author             627 non-null    string
#  4   news_content            1000 non-null   string
#  5   news_url                1000 non-null   string
#  6   news_category           1000 non-null   string
#  7   news_website            1000 non-null   string
#  8   note                    1000 non-null   string
# dtypes: string(9)
# memory usage: 70.4 KB

# %% [markdown]
# # 데이터 전처리

# %%
import json
import random
import re
from pprint import pprint

# %% [markdown]
# ## hankyung

# %%
def hankyung_atag_remove(x: re.Match) -> str:
    """한국경제 본문에서 a태그에서 텍스트만 남기고 나머지 태그 정보등을 제거하는 전처리 함수

    Args:
        x: 매칭된 문자열

    Returns:
        전처리된 문자열
    """

    x = x.group(1)
    x = re.sub(pattern=r' +', repl=' ', string=x)
    return x

# %%
idx = random.choice(range(len(hankyung_df)))
print(idx)
# Out:
# 339

# %%
print(hankyung_df.loc[idx, 'news_url'])
# Out:
# https://www.hankyung.com/article/2024102599451

# %%
pprint(hankyung_df.loc[idx, 'news_content'])
# Out:
# ('<div class="article-body" id="articletxt" itemprop="articleBody">\n'
#  ' “영원한 동맹도, 영원한 갑을(甲乙)도 없다.”\n'
#  ' <br/>\n'
#  ' <br/>\n'
#  ' 영국 ARM과 미국 퀄컴이 오는 12월 프로세서 개발 특허 라이선스 관련 소송을 앞두고 날 선 비방을 주고받고 있다. 반도체 설계도의 '
#  '밑그림인 ‘설계자산’(IP)을 판매하고 수수료를 받는 ARM과 IP를 활용해 칩을 개발하는 퀄컴은 오랜 기간 공생 관계를 유지했다.\n'
#  ' <figure class="article-figure">\n'
#  '  <div class="figure-img">\n'
#  '   <img alt=\'ARM·퀄컴 동맹 왜 깨졌나…"AI 반도체 시장 양보 못 해"\' '
#  'src="https://img.hankyung.com/photo/202410/AA.38433045.1.jpg"/>\n'
#  '  </div>\n'
#  ' </figure>\n'
#  ' 갈등이 불거진 건 인공지능(AI) 반도체 시대가 시작되면서부터다. AI 칩 설계·개발 주도권을 갖고 싶은 퀄컴이 ‘탈ARM’을 '
#  '시도했고, 최대 고객의 이탈 움직임에 ARM은 소송을 예고하며 압박하고 있다. AI 기기용 반도체 시장이 급성장하면서 기술력을 키워 '
#  '협력사 의존도를 낮추고 시장을 독식하려는 기업들의 움직임이 확산할 것이란 전망이 나온다.\n'
#  ' <br/>\n'
#  ' <br/>\n'
#  ' 25일 반도체업계에 따르면 ARM은 지난 23일 퀄컴에 라이선스 해지를 통보했다. 두 회사가 합의하지 못하면 퀄컴은 12월 22일부터 '
#  'ARM의 IP를 사용할 수 없다. 퀄컴은 ARM IP를 기반으로 칩을 개발하고 있다.\n'
#  ' <br/>\n'
#  ' <br/>\n'
#  ' ARM과 퀄컴은 글로벌 반도체 산업에서 가장 중요한 회사들로 꼽힌다. ARM은 세계 모바일 칩 IP의 99%를 점유하고 있다. 퀄컴은 '
#  'ARM의 IP를 기초로 애플리케이션프로세서(AP)를 만들어 삼성전자, 구글, 화웨이 등 안드로이드 기반 스마트폰 제조사에 공급한다. '
#  'ARM의 IP를 쓰지 못하면 AP 제작이 사실상 불가능하다.\n'
#  ' <br/>\n'
#  ' <br/>\n'
#  ' 2020년까지 두 회사는 핵심 협력사로서 서로 긴밀한 관계를 유지했다. 퀄컴은 ARM 모바일 IP 매출의 34%(2021년 말 기준)를 '
#  '차지하는 최대 고객사였다. 퀄컴은 자사 칩 제조 전 과정에 ARM 설계도를 활용했다. 하지만 2021년 퀄컴이 PC용 '
#  '중앙처리장치(CPU) 설계 전문 기업 누비아를 인수하자 상황이 바뀌었다. 퀄컴이 PC용 프로세서 개발 과정에서 ARM 의존도를 낮추는 '
#  '전략을 추진하면서 관계가 틀어졌다.\n'
#  ' <br/>\n'
#  ' <br/>\n'
#  ' ARM은 모바일 분야 의존도를 낮추기 위해 PC 칩 고객사 확대에 사활을 걸고 있다. ARM은 퀄컴과 합의를 시도했지만 실패했다. '
#  '2022년 8월 퀄컴에 계약 위반 및 상표권 침해 소송을 걸었다. 두 회사는 12월 본안 소송을 앞두고 있다.\n'
#  ' <br/>\n'
#  ' <br/>\n'
#  ' 두 회사의 갈등에 대해 반도체 업계에선 “급변하는 AI 반도체 산업의 단면”이란 분석이 나온다. AI PC·스마트폰 출하량이 늘면서 '
#  'AI 기기용 반도체 시장을 선점하려는 경쟁이 치열해지고 있다. 퀄컴뿐만 아니라 엔비디아, AMD 등도 AI PC용 프로세서 시장에 '
#  '뛰어들었다.\n'
#  ' <br/>\n'
#  ' <br/>\n'
#  ' 특정 고객사 의존도가 높은 것이 AI 반도체 시대엔 ‘부메랑’이 되고 있다는 분석도 있다. 퀄컴 입장에서는 ARM과의 소송 결과에 따라 '
#  '자사 칩이 들어간 고객사 제품의 출하 중단 사태를 맞을 수 있다. 마이크로소프트, 삼성 등 고객사가 출하 중단에 따른 피해 책임을 퀄컴에 '
#  '돌리면 2차 소송전으로 번질 수도 있다. 업계 관계자는 “특정 기업 거래 비중이 높으면 리스크도 커진다는 것을 ARM과 퀄컴 모두 '
#  '뼈저리게 느끼고 있을 것”이라고 말했다.\n'
#  ' <br/>\n'
#  ' <br/>\n'
#  ' ‘결국 기술력’이란 평가도 나온다. 반도체 기업 관계자는 “대만 TSMC가 고객사인 엔비디아 앞에서 설계 잘못을 지적할 수 있는 것은 '
#  '독보적인 생산 기술력을 갖췄기 때문”이라며 “AI 칩 시대엔 기술력에 따라 언제든지 갑과 을이 바뀔 수 있다”고 설명했다.\n'
#  ' <br/>\n'
#  ' <br/>\n'
#  ' 박의명 기자 uimyung@hankyung.com\n'
#  '</div>\n')

# %%
soup = BeautifulSoup(hankyung_df.loc[idx, 'news_content'], 'html.parser')
content = []

# ------------------------------------------------------------------------------------------------------------------------------------

# BeautifulSouo로 일부 tag 제거
# 동영상 제거
for tag in soup.find_all("div", {"class": "article-video"}):
    tag.decompose()

# 이미지 제거
for tag in soup.find_all("figure"):
    tag.decompose()

# 스크립트 제거
for tag in soup.find_all(lambda tag: tag.name == 'script'):
    tag.decompose()

# ------------------------------------------------------------------------------------------------------------------------------------

# 기자 이름 및 이메일 제거
# 하이퍼링크 제거
pattern_name_email = r'\w+@'

for s in soup.div.contents:
    if re.search(pattern=rf'({pattern_name_email})', string=s.text, flags=re.IGNORECASE) is not None:
        continue

    content.append(str(s))

# 양 끝자락에 있는 화이트스페이스 제거
content = ''.join(content).strip()

# amp; 제거
content = content.replace('amp;', '')

content = re.sub(pattern=r'\s+<a href=.*?>\n(.+?)\n\s+</a>\s+', repl=hankyung_atag_remove, string=content)

# 오른쪽 끝자락에 있는 r'\s*?(<br/>\s*?)+?$'패턴들을 제거
content = re.sub(pattern=r'\s*?(<br/>\s*?)+?$', repl='', string=content)

# 왼쪽 끝자락에 있는 ^\s*?(<br/>\s*?)+?패턴들을 제거
content = re.sub(pattern=r'^\s*?(<br/>\s*?)+?', repl='', string=content)

# 양 끝자락에 있는 화이트스페이스 제거
content = content.strip()
pprint(content)
# Out:
# ('“영원한 동맹도, 영원한 갑을(甲乙)도 없다.”\n'
#  ' <br/>\n'
#  '<br/>\n'
#  ' 영국 ARM과 미국 퀄컴이 오는 12월 프로세서 개발 특허 라이선스 관련 소송을 앞두고 날 선 비방을 주고받고 있다. 반도체 설계도의 '
#  '밑그림인 ‘설계자산’(IP)을 판매하고 수수료를 받는 ARM과 IP를 활용해 칩을 개발하는 퀄컴은 오랜 기간 공생 관계를 유지했다.\n'
#  ' \n'
#  ' 갈등이 불거진 건 인공지능(AI) 반도체 시대가 시작되면서부터다. AI 칩 설계·개발 주도권을 갖고 싶은 퀄컴이 ‘탈ARM’을 '
#  '시도했고, 최대 고객의 이탈 움직임에 ARM은 소송을 예고하며 압박하고 있다. AI 기기용 반도체 시장이 급성장하면서 기술력을 키워 '
#  '협력사 의존도를 낮추고 시장을 독식하려는 기업들의 움직임이 확산할 것이란 전망이 나온다.\n'
#  ' <br/>\n'
#  '<br/>\n'
#  ' 25일 반도체업계에 따르면 ARM은 지난 23일 퀄컴에 라이선스 해지를 통보했다. 두 회사가 합의하지 못하면 퀄컴은 12월 22일부터 '
#  'ARM의 IP를 사용할 수 없다. 퀄컴은 ARM IP를 기반으로 칩을 개발하고 있다.\n'
#  ' <br/>\n'
#  '<br/>\n'
#  ' ARM과 퀄컴은 글로벌 반도체 산업에서 가장 중요한 회사들로 꼽힌다. ARM은 세계 모바일 칩 IP의 99%를 점유하고 있다. 퀄컴은 '
#  'ARM의 IP를 기초로 애플리케이션프로세서(AP)를 만들어 삼성전자, 구글, 화웨이 등 안드로이드 기반 스마트폰 제조사에 공급한다. '
#  'ARM의 IP를 쓰지 못하면 AP 제작이 사실상 불가능하다.\n'
#  ' <br/>\n'
#  '<br/>\n'
#  ' 2020년까지 두 회사는 핵심 협력사로서 서로 긴밀한 관계를 유지했다. 퀄컴은 ARM 모바일 IP 매출의 34%(2021년 말 기준)를 '
#  '차지하는 최대 고객사였다. 퀄컴은 자사 칩 제조 전 과정에 ARM 설계도를 활용했다. 하지만 2021년 퀄컴이 PC용 '
#  '중앙처리장치(CPU) 설계 전문 기업 누비아를 인수하자 상황이 바뀌었다. 퀄컴이 PC용 프로세서 개발 과정에서 ARM 의존도를 낮추는 '
#  '전략을 추진하면서 관계가 틀어졌다.\n'
#  ' <br/>\n'
#  '<br/>\n'
#  ' ARM은 모바일 분야 의존도를 낮추기 위해 PC 칩 고객사 확대에 사활을 걸고 있다. ARM은 퀄컴과 합의를 시도했지만 실패했다. '
#  '2022년 8월 퀄컴에 계약 위반 및 상표권 침해 소송을 걸었다. 두 회사는 12월 본안 소송을 앞두고 있다.\n'
#  ' <br/>\n'
#  '<br/>\n'
#  ' 두 회사의 갈등에 대해 반도체 업계에선 “급변하는 AI 반도체 산업의 단면”이란 분석이 나온다. AI PC·스마트폰 출하량이 늘면서 '
#  'AI 기기용 반도체 시장을 선점하려는 경쟁이 치열해지고 있다. 퀄컴뿐만 아니라 엔비디아, AMD 등도 AI PC용 프로세서 시장에 '
#  '뛰어들었다.\n'
#  ' <br/>\n'
#  '<br/>\n'
#  ' 특정 고객사 의존도가 높은 것이 AI 반도체 시대엔 ‘부메랑’이 되고 있다는 분석도 있다. 퀄컴 입장에서는 ARM과의 소송 결과에 따라 '
#  '자사 칩이 들어간 고객사 제품의 출하 중단 사태를 맞을 수 있다. 마이크로소프트, 삼성 등 고객사가 출하 중단에 따른 피해 책임을 퀄컴에 '
#  '돌리면 2차 소송전으로 번질 수도 있다. 업계 관계자는 “특정 기업 거래 비중이 높으면 리스크도 커진다는 것을 ARM과 퀄컴 모두 '
#  '뼈저리게 느끼고 있을 것”이라고 말했다.\n'
#  ' <br/>\n'
#  '<br/>\n'
#  ' ‘결국 기술력’이란 평가도 나온다. 반도체 기업 관계자는 “대만 TSMC가 고객사인 엔비디아 앞에서 설계 잘못을 지적할 수 있는 것은 '
#  '독보적인 생산 기술력을 갖췄기 때문”이라며 “AI 칩 시대엔 기술력에 따라 언제든지 갑과 을이 바뀔 수 있다”고 설명했다.')

# %% [markdown]
# ## maekyung

# %%
idx = random.choice(range(len(maekyung_df)))
print(idx)
# Out:
# 2193

# %%
print(maekyung_df.loc[idx, 'news_url'])
# Out:
# https://stock.mk.co.kr/news/view/472215

# %%
pprint(maekyung_df.loc[idx, 'news_content'])
# Out:
# ('<div class="news_detail_wrap">\n'
#  ' <div style="display:box;border-left:solid 4px rgb(228, 228, '
#  '228);padding-left: 20px; padding-right: 20px;">\n'
#  '  올 하반기부터 3년 적자 탈출 기대\n'
#  '  <br/>\n'
#  '  OLED 출하량 확대에\n'
#  '  <br/>\n'
#  '  2분기 영업적자 전분기 대비 절반 수준될 듯\n'
#  ' </div>\n'
#  ' <br/>\n'
#  ' <br/>\n'
#  ' <div style="width:100%; text-align: center;">\n'
#  '  <figure>\n'
#  '   <img '
#  'src="https://wimg.mk.co.kr/news/cms/202407/03/news-p.v1.20240703.bdddc84838464ca5862f905812fa6fae_P1.jpg" '
#  'style="max-width:100%;"/>\n'
#  '   <figcaption>\n'
#  '   </figcaption>\n'
#  '  </figure>\n'
#  ' </div>\n'
#  ' <br/>\n'
#  ' <br/>\n'
#  ' LG디스플레이가 올 2분기 이후 실적 전망 상향에 주가가 강세를 보이고 있다. LG디스플레이는 3일 11시30분 기준 전일대비 4.4% '
#  '오른 1만2280만원에 거래되고 있다.\n'
#  ' <br/>\n'
#  ' <br/>\n'
#  ' LG디스플레이 주가는 2분기 실적 컨센서스가 올라가면서 최근 한달간 21%가 오른 바 있다.\n'
#  ' <br/>\n'
#  ' <br/>\n'
#  ' KB증권은 LG디스플레이 2분기 영업적자는 전분기 4695억원에 비해서 절반으로 축소된 2345억원을 기록할 것으로 전망했다.\n'
#  ' <br/>\n'
#  ' <br/>\n'
#  ' 당초 컨센서스인 3500억원 적자에 비해 큰 폭으로 줄어든 수치다. 적자 규모가 눈에 띄게 감소하는 요인은 OLED패널 출하량 증가에 '
#  '있다.\n'
#  ' <br/>\n'
#  ' <br/>\n'
#  ' 김동원 KB증권 연구원은 “LG디스플레이의 이번 분기 대형 OLED 출하량은 전년대비 54% 증가할 것으로 보이며 중소형 OLED패널 '
#  '출하량 역시 51% 늘어날 것으로 전망된다”고 말했다.\n'
#  ' <br/>\n'
#  ' <br/>\n'
#  ' 특히 올해 애플에 공급하는 OLED 패널이 크게 늘고 LG전자의 TV 패널 주문이 확대돼 올 하반기 흑자전망에 대한 기대도 나오고 '
#  '있다.\n'
#  ' <br/>\n'
#  ' <br/>\n'
#  ' 중국발 저가 디스플레이 패널 공세로 LG디스플레이는 2021년 하반기 이후 적자를 기록한 바 있다.\n'
#  ' <br/>\n'
#  ' <br/>\n'
#  ' 김 연구원은 “중형 (태블릿 PC) OLED 안정적 물량확보와 중소형 OLED 점유율 확대 및 자동차 디스플레이의 OLED 매출 비중 '
#  '확대로 내년부터 LG디스플레이 흑자기조 정착이 예상된다”고 말했다.\n'
#  ' <br/>\n'
#  ' <br/>\n'
#  ' <br/>\n'
#  ' <br/>\n'
#  ' <script>\n'
#  '  //코스콤 공시 사용\n'
#  "                                $('#news_view').on('load', function() {\n"
#  '                                    if(this.contentDocument) {\n'
#  '                                        '
#  '$(this).height(this.contentDocument.documentElement.scrollHeight);\n'
#  '                                    }\n'
#  '                                    else {\n'
#  '                                        '
#  '$(this).height(this.contentWindow.document.body.scrollHeight);\n'
#  '                                    }\n'
#  '                                });\n'
#  ' </script>\n'
#  ' <!--                            <p>-->\n'
#  ' <!--                                [ⓒ 매일경제 & mk.co.kr, 무단전재 및 재배포 금지]-->\n'
#  ' <!--                            </p>-->\n'
#  '</div>\n')

# %%
soup = BeautifulSoup(maekyung_df.loc[idx, 'news_content'], 'html.parser')

# ------------------------------------------------------------------------------------------------------------------------------------

# BeautifulSouo로 일부 tag 제거
# 이미지 제거
for tag in soup.find_all(lambda tag: tag.name == 'div' and tag.has_attr('style') and tag['style'] == 'width:100%; text-align: center;'):
    tag.decompose()

# 스크립트 제거
for tag in soup.find_all(lambda tag: tag.name == 'script'):
    tag.decompose()

# 주석 제거
for comment in soup.find_all(string=lambda text: isinstance(text, Comment)):
    comment.extract()

# MK시그널 링크 제거
for tag in soup.find_all('a', {"class": "ix-editor-text-link"}):
    tag.decompose()

# ------------------------------------------------------------------------------------------------------------------------------------

# replace 및 정규표현식으로 제거
# 본문 태그 제거 및 양 끝에 있는 \n같은 화이트스페이스 제거
content = [str(s) for s in soup.div.contents]
content = ''.join(content).strip()

# [김진우 기자], [김진우 기자 / 권용희 기자] 같은 불필요한 정보 제거
content = re.sub(pattern=r'\[.+?/?.+?기자\]', repl='', string=content)

# MK시그널의 쓰잘데기 없는 광고 문구 제거
content = re.sub(pattern=r'※ 매일경제 AI기자.*?앱을 다운로드하세요\!', repl='', string=content)
content = re.sub(pattern=r'이 종목의 향후 매매신호를 받으려면 MK시그널.*?실시간으로 확인할 수 있습니다\.', repl='', string=content)
content = re.sub(pattern=r'MK시그널은 AI가 국내·미국 주식.*?정보 서비스입니다\.', repl='', string=content)
content = re.sub(pattern=r'국내 주식과 더불어 미국 주식.*?신호 받아보세요\!', repl='', string=content)
content = re.sub(pattern=r'인공지능\(AI\) 기반 매매신호 제공 앱.*?투자를 시작하세요\!', repl='', string=content)
content = re.sub(pattern=r'MK시그널 현재.*?진행중\!', repl='', string=content)

# '나현준의 데이터로 세상 읽기'에서 불필요한 정보 제거
content = re.sub(pattern=r'◆\s*매경 포커스\s*◆', repl='', string=content)

# amp; 제거
content = content.replace('amp;', '')

# 과도한 <br/>\n들을 줄이기
content = re.sub(pattern=r'(\s+<br/>){3,}', repl=r"\n <br/>\n<br/>", string=content)

# 양 끝자락에 있는 화이트스페이스 제거
content = content.strip()

# 오른쪽 끝자락에 있는 r'\s*?(<br/>\s*?)+?$'패턴들을 제거
content = re.sub(pattern=r'\s*?(<br/>\s*?)+?$', repl='', string=content)

# 왼쪽 끝자락에 있는 ^\s*?(<br/>\s*?)+?패턴들을 제거
content = re.sub(pattern=r'^\s*?(<br/>\s*?)+?', repl='', string=content)

# 기자 이름 제거
content = re.sub(r'[가-힣]+ 기자$', repl='', string=content)

# 오른쪽 끝자락에 있는 r'\s*?(<br/>\s*?)+?$'패턴들을 제거
content = re.sub(pattern=r'\s*?(<br/>\s*?)+?$', repl='', string=content)

# 왼쪽 끝자락에 있는 ^\s*?(<br/>\s*?)+?패턴들을 제거
content = re.sub(pattern=r'^\s*?(<br/>\s*?)+?', repl='', string=content)

# 양 끝자락에 있는 화이트스페이스 제거
content = content.strip()
pprint(content)
# Out:
# ('<div style="display:box;border-left:solid 4px rgb(228, 228, '
#  '228);padding-left: 20px; padding-right: 20px;">\n'
#  '  올 하반기부터 3년 적자 탈출 기대\n'
#  '  <br/>\n'
#  '  OLED 출하량 확대에\n'
#  '  <br/>\n'
#  '  2분기 영업적자 전분기 대비 절반 수준될 듯\n'
#  ' </div>\n'
#  ' <br/>\n'
#  '<br/>\n'
#  ' LG디스플레이가 올 2분기 이후 실적 전망 상향에 주가가 강세를 보이고 있다. LG디스플레이는 3일 11시30분 기준 전일대비 4.4% '
#  '오른 1만2280만원에 거래되고 있다.\n'
#  ' <br/>\n'
#  '<br/>\n'
#  ' LG디스플레이 주가는 2분기 실적 컨센서스가 올라가면서 최근 한달간 21%가 오른 바 있다.\n'
#  ' <br/>\n'
#  '<br/>\n'
#  ' KB증권은 LG디스플레이 2분기 영업적자는 전분기 4695억원에 비해서 절반으로 축소된 2345억원을 기록할 것으로 전망했다.\n'
#  ' <br/>\n'
#  '<br/>\n'
#  ' 당초 컨센서스인 3500억원 적자에 비해 큰 폭으로 줄어든 수치다. 적자 규모가 눈에 띄게 감소하는 요인은 OLED패널 출하량 증가에 '
#  '있다.\n'
#  ' <br/>\n'
#  '<br/>\n'
#  ' 김동원 KB증권 연구원은 “LG디스플레이의 이번 분기 대형 OLED 출하량은 전년대비 54% 증가할 것으로 보이며 중소형 OLED패널 '
#  '출하량 역시 51% 늘어날 것으로 전망된다”고 말했다.\n'
#  ' <br/>\n'
#  '<br/>\n'
#  ' 특히 올해 애플에 공급하는 OLED 패널이 크게 늘고 LG전자의 TV 패널 주문이 확대돼 올 하반기 흑자전망에 대한 기대도 나오고 '
#  '있다.\n'
#  ' <br/>\n'
#  '<br/>\n'
#  ' 중국발 저가 디스플레이 패널 공세로 LG디스플레이는 2021년 하반기 이후 적자를 기록한 바 있다.\n'
#  ' <br/>\n'
#  '<br/>\n'
#  ' 김 연구원은 “중형 (태블릿 PC) OLED 안정적 물량확보와 중소형 OLED 점유율 확대 및 자동차 디스플레이의 OLED 매출 비중 '
#  '확대로 내년부터 LG디스플레이 흑자기조 정착이 예상된다”고 말했다.')

# %% [markdown]
# ## yna

# %%
idx = random.choice(range(len(yna_df)))
print(idx)
# Out:
# 896

# %%
print(yna_df.loc[idx, 'news_url'])
# Out:
# https://www.yna.co.kr/view/AKR20241217016000072?section=market-plus/global-market

# %%
pprint(yna_df.loc[idx, 'news_content'])
# Out:
# ('<article class="story-news article">\n'
#  ' <div class="writer-zone01" id="newsWriterCarousel01">\n'
#  '  <div class="list">\n'
#  '   <div class="li">\n'
#  '    <figure class="img-con">\n'
#  '     <img alt="이지헌 기자" '
#  'src="https://img6.yna.co.kr/reporter/36343139393937.jpg"/>\n'
#  '    </figure>\n'
#  '    <div class="txt-con">\n'
#  '     <a class="tit-name" data-stat-code="article_writer" '
#  'href="https://www.yna.co.kr/reporter/index?id=36343139393937">\n'
#  '      이지헌\n'
#  '     </a>\n'
#  '     <span class="unit">\n'
#  '      기자\n'
#  '     </span>\n'
#  '    </div>\n'
#  '   </div>\n'
#  '  </div>\n'
#  ' </div>\n'
#  ' <div class="tit-sub">\n'
#  '  <h2 class="tit">\n'
#  '   프리랜드 "美와 관세전쟁 앞두고 \'정치적 술수\' 대신 재정 여력 둬야"\n'
#  '  </h2>\n'
#  '  <h2 class="tit">\n'
#  "   '인기 하락' 트뤼도, 정치적 위기 가중…후임엔 측근 임명\n"
#  '  </h2>\n'
#  ' </div>\n'
#  ' <div class="comp-box photo-group">\n'
#  '  <figure class="image-zone" '
#  'data-mapping-filename="AKR20241217016000072_01_i_P2.jpg" '
#  'data-stat-code="mapping_photo">\n'
#  '   <div class="img-con">\n'
#  '    <span class="img">\n'
#  '     <img alt="사임한 크리스티아 프리랜드 부총리 겸 재무장관" '
#  'src="//img0.yna.co.kr/etc/inner/KR/2024/12/17/AKR20241217016000072_01_i_P4.jpg"/>\n'
#  '    </span>\n'
#  '   </div>\n'
#  '   <figcaption class="desc-con">\n'
#  '    <strong class="tit-cap">\n'
#  '     사임한 크리스티아 프리랜드 부총리 겸 재무장관\n'
#  '    </strong>\n'
#  '    <p class="txt-desc">\n'
#  '     [로이터 연합뉴스 자료사진]\n'
#  '    </p>\n'
#  '    <p class="txt-link" data-mapping-link="">\n'
#  '     <a data-webview-link="true" href="" target="_blank" title="새창">\n'
#  '     </a>\n'
#  '    </p>\n'
#  '   </figcaption>\n'
#  '  </figure>\n'
#  ' </div>\n'
#  ' <p>\n'
#  '  (뉴욕=연합뉴스) 이지헌 특파원 = 크리스티아 프리랜드(56) 캐나다 부총리 겸 재무장관이 도널드 트럼프 차기 미국 행정부가 예고한 '
#  '고율 관세 대응 문제 등을 두고 쥐스탱 트뤼도 총리와 충돌한 뒤 16일(현지시간) 전격 사임했다.\n'
#  ' </p>\n'
#  ' <p>\n'
#  '  프리랜드 장관은 이날 공개한 사직서에서 "트뤼도 총리가 지난 13일 내게 다른 직위를 제안했고, 이에 대해 심사숙고한 결과 내각에서 '
#  '사임하는 게 정직하고 실행가능한 길이라고 결론지었다"라고 밝혔다.\n'
#  ' </p>\n'
#  ' <p>\n'
#  '  프리랜드 장관은 사직서에서 "우리나라는 오늘날 심각한 도전에 직면해 있다"며 "차기 미 행정부는 25% 관세 부과 위협을 포함해 '
#  '공격적인 보호주의 정책을 추구하고 있다"라고 말했다.\n'
#  ' </p>\n'
#  ' <aside class="aside-bnr05">\n'
#  '  <span class="blind">\n'
#  '   광고\n'
#  '  </span>\n'
#  '  <div class="con ads-article01">\n'
#  '   <script async="" '
#  'src="https://ad.yna.co.kr/RealMedia/ads/adstream_sx.ads/yna/economy@Frame2?ads-article01">\n'
#  '   </script>\n'
#  '  </div>\n'
#  ' </aside>\n'
#  ' <p>\n'
#  '  이어 "우리는 이 위협을 극도로 심각하게 여길 필요가 있다"며 "이는 향후 다가올 수 있는 관세 전쟁에 필요한 재원을 확보해두기 위해 '
#  '재정 여력을 유지해야 함을 의미한다"라고 강조했다.\n'
#  ' </p>\n'
#  ' <p>\n'
#  '  그러면서 "이는 비용이 많이 드는 정치적 술수를 피하는 것을 의미한다"라고 부연했다.\n'
#  ' </p>\n'
#  ' <p>\n'
#  '  건전 재정을 유지하지 않는 것은 정부가 감당할 수도 없을 뿐만 아니라 정부가 상황의 심각성을 인식하고 있는지 국민이 의심하게 만들 '
#  '것이라고 그는 지적했다.\n'
#  '  <br/>\n'
#  ' </p>\n'
#  ' <div class="comp-box photo-group">\n'
#  '  <figure class="image-zone" '
#  'data-mapping-filename="AKR20241217016000072_02_i_P2.jpg" '
#  'data-stat-code="mapping_photo">\n'
#  '   <div class="img-con">\n'
#  '    <span class="img">\n'
#  '     <img alt="쥐시탱 트뤼도 캐나다 총리" '
#  'src="//img9.yna.co.kr/etc/inner/KR/2024/12/17/AKR20241217016000072_02_i_P4.jpg"/>\n'
#  '    </span>\n'
#  '   </div>\n'
#  '   <figcaption class="desc-con">\n'
#  '    <strong class="tit-cap">\n'
#  '     쥐시탱 트뤼도 캐나다 총리\n'
#  '    </strong>\n'
#  '    <p class="txt-desc">\n'
#  '     [로이터 연합뉴스 자료사진]\n'
#  '    </p>\n'
#  '    <p class="txt-link" data-mapping-link="">\n'
#  '     <a data-webview-link="true" href="" target="_blank" title="새창">\n'
#  '     </a>\n'
#  '    </p>\n'
#  '   </figcaption>\n'
#  '  </figure>\n'
#  ' </div>\n'
#  ' <p>\n'
#  '  이날 프리랜드 장관의 사임은 재무부의 연방정부 재정 상황에 대한 의회 보고를 앞두고 이뤄졌다.\n'
#  ' </p>\n'
#  ' <p>\n'
#  '  재정지출 확대를 둘러싸고 트뤼도 총리와 이견을 보인 가운데 현 상황에서 재정을 푸는 부양책이 부작용만 초래할 것이라고 반대 의견을 '
#  '고수하다가 결국 장관직에서 사퇴한 것으로 풀이된다.\n'
#  ' </p>\n'
#  ' <p>\n'
#  '  한편 캐나다 정부는 이날 2023∼2024년도 캐나다 정부 재정적자 규모가 619억 캐나다달러(약 62조5천억원)라고 발표했다. 이는 '
#  '전문가 예상을 웃도는 적자 규모다.\n'
#  ' </p>\n'
#  ' <p>\n'
#  '  후임 재무장관으로는 트뤼도 총리 핵심 측근인 도미니크 르블랑 공공안전부 장관이 곧바로 임명됐다.\n'
#  ' </p>\n'
#  ' <p>\n'
#  '  로이터 통신은 "프리랜드 장관의 사퇴는 트뤼도 총리가 지난 2015년 취임한 후 직면한 가장 큰 위기 중 하나"라며 "다음 총선에서 '
#  '야당인 보수당에게 패배할 것으로 예상되는 상황에서 핵심 동맹을 잃은 것"이라고 평가했다.\n'
#  ' </p>\n'
#  ' <p>\n'
#  '  pan@yna.co.kr\n'
#  '  <br/>\n'
#  ' </p>\n'
#  ' <p class="txt-copyright adrs">\n'
#  '  <a class="txt03" data-stat-code="copyright_jebo_view" '
#  'href="https://www.yna.co.kr/board/jebo/index">\n'
#  '   제보는 카카오톡 okjebo\n'
#  '  </a>\n'
#  '  <em class="txt01">\n'
#  '   &lt;저작권자(c) 연합뉴스,\n'
#  '  </em>\n'
#  '  <em class="txt02">\n'
#  '   무단 전재-재배포, AI 학습 및 활용 금지&gt;\n'
#  '  </em>\n'
#  '  <span class="date">\n'
#  '   2024/12/17 07:44 송고\n'
#  '  </span>\n'
#  ' </p>\n'
#  '</article>\n')

# %%
soup = BeautifulSoup(yna_df.loc[idx, 'news_content'], 'html.parser')
content = []

# ------------------------------------------------------------------------------------------------------------------------------------

# BeautifulSouo로 일부 tag 제거
# 기자 이름 제거
for tag in soup.find_all(lambda tag: tag.has_attr('id') and re.search(pattern=r'newsWriter', string=tag['id']) is not None):
    tag.decompose()

# 이미지 제거
for tag in soup.find_all("div", {"class": "comp-box photo-group"}):
    tag.decompose()

# 동영상 제거
for tag in soup.find_all("div", {"class": "comp-box youtube-group"}):
    tag.decompose()

# 중간 광고 제거
for tag in soup.find_all("aside"):
    tag.decompose()

# 관련 기사 제거
for tag in soup.find_all("div", {"class": "related-zone rel"}):
    tag.decompose()

# 제보 및 저작권 제거
for tag in soup.find_all("p", {"class": "txt-copyright adrs"}):
    tag.decompose()

# ------------------------------------------------------------------------------------------------------------------------------------

# 기자 이름 및 이메일 제거
# 하이퍼링크 제거
pattern_name_email = r'\w+@'

for s in soup.article.contents:
    if re.search(pattern=rf'({pattern_name_email})', string=s.text, flags=re.IGNORECASE) is not None:
        continue

    content.append(str(s))

# 양 끝자락에 있는 화이트스페이스 제거
content = ''.join(content).strip()

# amp; 제거
content = content.replace('amp;', '')

# 끝자락에 있는 <br/> 제거
content = re.sub(pattern=r'<p>\s*?<br/>\s*?</p>$', repl='', string=content)

# 양 끝자락에 있는 화이트스페이스 제거
content = content.strip()
pprint(content)
# Out:
# ('<div class="tit-sub">\n'
#  '<h2 class="tit">\n'
#  '   프리랜드 "美와 관세전쟁 앞두고 \'정치적 술수\' 대신 재정 여력 둬야"\n'
#  '  </h2>\n'
#  '<h2 class="tit">\n'
#  "   '인기 하락' 트뤼도, 정치적 위기 가중…후임엔 측근 임명\n"
#  '  </h2>\n'
#  '</div>\n'
#  '\n'
#  '<p>\n'
#  '  (뉴욕=연합뉴스) 이지헌 특파원 = 크리스티아 프리랜드(56) 캐나다 부총리 겸 재무장관이 도널드 트럼프 차기 미국 행정부가 예고한 '
#  '고율 관세 대응 문제 등을 두고 쥐스탱 트뤼도 총리와 충돌한 뒤 16일(현지시간) 전격 사임했다.\n'
#  ' </p>\n'
#  '<p>\n'
#  '  프리랜드 장관은 이날 공개한 사직서에서 "트뤼도 총리가 지난 13일 내게 다른 직위를 제안했고, 이에 대해 심사숙고한 결과 내각에서 '
#  '사임하는 게 정직하고 실행가능한 길이라고 결론지었다"라고 밝혔다.\n'
#  ' </p>\n'
#  '<p>\n'
#  '  프리랜드 장관은 사직서에서 "우리나라는 오늘날 심각한 도전에 직면해 있다"며 "차기 미 행정부는 25% 관세 부과 위협을 포함해 '
#  '공격적인 보호주의 정책을 추구하고 있다"라고 말했다.\n'
#  ' </p>\n'
#  '\n'
#  '<p>\n'
#  '  이어 "우리는 이 위협을 극도로 심각하게 여길 필요가 있다"며 "이는 향후 다가올 수 있는 관세 전쟁에 필요한 재원을 확보해두기 위해 '
#  '재정 여력을 유지해야 함을 의미한다"라고 강조했다.\n'
#  ' </p>\n'
#  '<p>\n'
#  '  그러면서 "이는 비용이 많이 드는 정치적 술수를 피하는 것을 의미한다"라고 부연했다.\n'
#  ' </p>\n'
#  '<p>\n'
#  '  건전 재정을 유지하지 않는 것은 정부가 감당할 수도 없을 뿐만 아니라 정부가 상황의 심각성을 인식하고 있는지 국민이 의심하게 만들 '
#  '것이라고 그는 지적했다.\n'
#  '  <br/>\n'
#  '</p>\n'
#  '\n'
#  '<p>\n'
#  '  이날 프리랜드 장관의 사임은 재무부의 연방정부 재정 상황에 대한 의회 보고를 앞두고 이뤄졌다.\n'
#  ' </p>\n'
#  '<p>\n'
#  '  재정지출 확대를 둘러싸고 트뤼도 총리와 이견을 보인 가운데 현 상황에서 재정을 푸는 부양책이 부작용만 초래할 것이라고 반대 의견을 '
#  '고수하다가 결국 장관직에서 사퇴한 것으로 풀이된다.\n'
#  ' </p>\n'
#  '<p>\n'
#  '  한편 캐나다 정부는 이날 2023∼2024년도 캐나다 정부 재정적자 규모가 619억 캐나다달러(약 62조5천억원)라고 발표했다. 이는 '
#  '전문가 예상을 웃도는 적자 규모다.\n'
#  ' </p>\n'
#  '<p>\n'
#  '  후임 재무장관으로는 트뤼도 총리 핵심 측근인 도미니크 르블랑 공공안전부 장관이 곧바로 임명됐다.\n'
#  ' </p>\n'
#  '<p>\n'
#  '  로이터 통신은 "프리랜드 장관의 사퇴는 트뤼도 총리가 지난 2015년 취임한 후 직면한 가장 큰 위기 중 하나"라며 "다음 총선에서 '
#  '야당인 보수당에게 패배할 것으로 예상되는 상황에서 핵심 동맹을 잃은 것"이라고 평가했다.\n'
#  ' </p>')

# %% [markdown]
# # Original 데이터의 메타 데이터들을 수정

# %%
import json

# %%
website_dict = {'hankyung': "한국경제", "maekyung": "매일경제", "yna": "연합뉴스"}

# %%
for website in ('hankyung', 'maekyung', 'yna'):
    new_data = []
    data_path = rf'C:\Users\RMARKET\Desktop\finance-advisor-bot\datas\news_data\{website}_data_origin.json'
    save_path = rf'C:\Users\RMARKET\Desktop\finance-advisor-bot\datas\news_data\{website}_data.json'
    with open(data_path, mode='r', encoding='utf-8') as f:
        data = json.load(f)

    for d in data:
        d['news_website'] = website_dict[d['news_website']]
        new_data.append(d)

    with open(save_path, mode='w', encoding='utf-8') as f:
        json.dump(new_data, f, ensure_ascii=False, indent=4)
# Out:
# 7960
# 3740
# 1000
